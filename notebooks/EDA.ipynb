# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.set_option('display.max_colwidth', 0)

# %%
train = pd.read_csv('../data/input/train.csv.zip')

# %%
train['length'] = train.question_text.apply(len)
train['upper_count'] = train.question_text.apply(lambda x: sum(map(str.isupper, x)))
train['upper_rate'] = train.upper_count / train.length

# %%
train.query('target == 1').sample(100)
# Out:
#                           qid  \
# 849991   a689e9911119d363a883
# 600926   75b4ac22dd336feef248
# 602308   75f763343c83aa5b686a
# 882293   acd9d5ba80f463c47cae
# 707717   8a922d2283b008a3b4ab
# 1256615  f641204420136c4abd5c
# 1173177  e5e798114546cf4a996d
# 905155   b15ea1d26a468f20c12a
# 628129   7b029edc44ddb3255cf1
# 1204960  ec2c5899f503e6c1d17a
# 1162788  e3d6aad32d895398e404
# 664728   822d7ed0718c49c25b4c
# 769067   96add71ddbedbda92c95
# 34530    06c0fd65a8d77faacbeb
# 549181   6b96e372a63214761ba9
# 917066   b3b195529fd064c3b73d
# 80651    0fcc447b2726b7b4bc7b
# 58323    0b71a8c44c8bbff9d258
# 1145774  e07f6ce01a4159b5e477
# 336334   41e7a336f90b9be63f52
# 388696   4c2580e837d506dbfd16
# 1007935  c582e8a82f3bde871b96
# 975889   bf3129348c887b5aacb2
# 906065   b18aa83c496e923833c1
# 321898   3f15e44e2de2317f4ac2
# 723052   8d8e8c0d60c699501f32
# 228685   2cb8aeba01cc1ab16157
# 1025692  c8fccb1544b402ee914c
# 451843   5880c0ce89048baf8e5b
# 1094870  d693d18fbaa9fb5bf5b5
# ...
